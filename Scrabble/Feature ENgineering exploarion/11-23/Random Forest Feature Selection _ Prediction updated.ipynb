# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_excel(r"hist_player_score_final_data_11-23 with board metrics.xlsx")
df.rename(columns={"hist_player_score": "hist_player_performance"}, inplace=True)
df.index = df.game_id

# %%
df
# Out:
#          game_id       first time_control_name game_end_reason lexicon  \
# game_id
# 43828      43828    HastyBot        ultrablitz        RESIGNED   CSW21
# 5765        5765  0927399533           regular            TIME   CSW21
# 40264      40264   BetterBot           regular            TIME   CSW21
# 44376      44376  0927399533           regular        STANDARD   CSW21
# 32633      32633   BetterBot           regular        STANDARD   CSW21
# ...          ...         ...               ...             ...     ...
# 7264        7264        zuzu           regular        STANDARD   CSW21
# 66022      66022     zyzzyva           regular        STANDARD   NWL20
# 2581        2581     STEEBot           regular        STANDARD   NWL20
# 54204      54204     STEEBot           regular        STANDARD   NWL20
# 23789      23789     zyzzyva           regular        STANDARD   NWL20
#
#          initial_time_seconds  increment_seconds rating_mode  \
# game_id
# 43828                      15                  0       RATED
# 5765                     1200                  0       RATED
# 40264                    1200                  0       RATED
# 44376                    1200                  0       RATED
# 32633                    1200                  0       RATED
# ...                       ...                ...         ...
# 7264                     1200                  0       RATED
# 66022                    1380                  0       RATED
# 2581                     1380                  0       RATED
# 54204                    1200                  0       RATED
# 23789                    1200                  0       RATED
#
#          max_overtime_minutes  game_duration_seconds Bot_nickname  \
# game_id
# 43828                       1              61.405180     HastyBot
# 5765                        1            1268.252752    BetterBot
# 40264                       1            1262.786704    BetterBot
# 44376                       1            1209.746654    BetterBot
# 32633                       1            1231.166683    BetterBot
# ...                       ...                    ...          ...
# 7264                        1             683.258274     HastyBot
# 66022                       1             626.274697      STEEBot
# 2581                        1             775.765387      STEEBot
# 54204                       1             624.940244      STEEBot
# 23789                       1             589.657785      STEEBot
#
#         Player_nickname  Bot_turns_count  Player_turns_count  Bot_max_point  \
# game_id
# 43828        0188889876               16                  16             72
# 5765         0927399533               11                  12             92
# 40264        0927399533               12                  12             74
# 44376        0927399533               15                  16            102
# 32633        0927399533               15                  16             85
# ...                 ...              ...                 ...            ...
# 7264               zuzu               13                  14             77
# 66022           zyzzyva               13                  13             78
# 2581            zyzzyva               12                  11             70
# 54204           zyzzyva               14                  14             70
# 23789           zyzzyva               12                  13             71
#
#          Player_max_point  Bot_min_point  Player_min_point  Bot_avg_bingo  \
# game_id
# 43828                  14              0               -10       0.062500
# 5765                   35             16               -10       0.272727
# 40264                  36              8               -10       0.166667
# 44376                  75              8               -10       0.125000
# 32633                  85              6               -10       0.066667
# ...                   ...            ...               ...            ...
# 7264                   78             10                 0       0.076923
# 66022                  66              0                 0       0.142857
# 2581                   76             13                17       0.076923
# 54204                  73              0                 0       0.000000
# 23789                  92              9                 2       0.083333
#
#          Player_avg_bingo  Bot_word_len  Player_word_len  \
# game_id
# 43828            0.000000      4.187500         0.312500
# 5765             0.000000      4.090909         2.250000
# 40264            0.000000      4.166667         3.000000
# 44376            0.062500      3.750000         2.437500
# 32633            0.117647      3.400000         2.823529
# ...                   ...           ...              ...
# 7264             0.066667      3.846154         3.200000
# 66022            0.076923      3.285714         3.846154
# 2581             0.181818      3.923077         4.000000
# 54204            0.133333      3.571429         3.200000
# 23789            0.071429      3.916667         3.714286
#
#          Bot_count_letters_JQXZ  Player_count_letters_JQXZ  \
# game_id
# 43828                         2                          0
# 5765                          4                          0
# 40264                         0                          2
# 44376                         4                          0
# 32633                         3                          1
# ...                         ...                        ...
# 7264                          3                          1
# 66022                         3                          1
# 2581                          3                          1
# 54204                         2                          2
# 23789                         3                          1
#
#          Bot_rack_used_rate  Player_rack_used_rate  Bot_win  Player_win  \
# game_id
# 43828              0.638095               0.178571        1           0
# 5765               0.584416               0.482143        1           0
# 40264              0.595238               0.467532        1           0
# 44376              0.625397               0.396825        1           0
# 32633              0.520952               0.519048        0           1
# ...                     ...                    ...      ...         ...
# 7264               0.549451               0.538462        1           0
# 66022              0.649351               0.595238        1           0
# 2581               0.642857               0.571429        0           1
# 54204              0.565934               0.582418        0           1
# 23789              0.559524               0.637363        0           1
#
#          Bot_game  Player_game  Bot_score  Player_score  Bot_rating  \
# game_id
# 43828       14112            1        472            15        2148
# 5765         4847            1        462           141        2012
# 40264        4871            2        356           212        1966
# 44376        5327            3        535           227        2090
# 32633        5336            4        383           391        2114
# ...           ...          ...        ...           ...         ...
# 7264        15306            7        414           327        2231
# 66022         573            1        393           357        1859
# 2581          579            2        358           438        1863
# 54204        2119            3        357           412        1856
# 23789        2126            4        362           391        1838
#
#          Player_rating           created_at  hist_player_performance  \
# game_id
# 43828           1979.0  2022-09-11 13:06:11                   1700.0
# 5765            1447.0  2022-08-09 14:25:28                   1700.0
# 40264           1408.0  2022-08-09 15:26:54                   1691.2
# 44376           1372.0  2022-08-10 16:28:43                   1677.8
# 32633           1367.0  2022-08-10 16:49:00                   1676.8
# ...                ...                  ...                      ...
# 7264            1855.0  2022-09-13 09:23:17                   1750.7
# 66022           1641.0  2022-07-28 18:47:59                   1700.0
# 2581            1637.0  2022-07-28 18:58:36                   1675.9
# 54204           1626.0  2022-08-01 01:07:41                   1732.2
# 23789           1641.0  2022-08-01 01:18:19                   1787.8
#
#          Bot_Double_Word  Bot_Triple_Word  Bot_Double_Letter  \
# game_id
# 43828                  4                5                  8
# 5765                   2                3                  7
# 40264                  7                0                  4
# 44376                  6                4                  9
# 32633                  7                1                  6
# ...                  ...              ...                ...
# 7264                   5                2                  5
# 66022                  5                1                  5
# 2581                   5                2                  6
# 54204                  6                3                  5
# 23789                  6                2                  3
#
#          Bot_Triple_Letter  Player_Double_Word  Player_Triple_Word  \
# game_id
# 43828                    4                   0                   0
# 5765                     5                   4                   2
# 40264                    6                   3                   4
# 44376                    5                   4                   3
# 32633                    5                   6                   5
# ...                    ...                 ...                 ...
# 7264                     4                   5                   5
# 66022                    2                   6                   3
# 2581                     5                   3                   4
# 54204                    4                   9                   1
# 23789                    5                   5                   5
#
#          Player_Double_Letter  Player_Triple_Letter
# game_id
# 43828                       1                     1
# 5765                        3                     0
# 40264                       5                     5
# 44376                       9                     0
# 32633                       4                     2
# ...                       ...                   ...
# 7264                        4                     1
# 66022                       4                     1
# 2581                        6                     5
# 54204                       5                     4
# 23789                       6                     3
#
# [72773 rows x 44 columns]

# %%
df[df["game_id"] == 2]
# Out:
#          game_id  first time_control_name game_end_reason lexicon  \
# game_id
# 2              2  Super           regular        STANDARD   CSW21
#
#          initial_time_seconds  increment_seconds rating_mode  \
# game_id
# 2                        3600                  0       RATED
#
#          max_overtime_minutes  game_duration_seconds Bot_nickname  \
# game_id
# 2                           1             364.214418    BetterBot
#
#         Player_nickname  Bot_turns_count  Player_turns_count  Bot_max_point  \
# game_id
# 2                 Super               12                  13             85
#
#          Player_max_point  Bot_min_point  Player_min_point  Bot_avg_bingo  \
# game_id
# 2                      94              8                 0           0.25
#
#          Player_avg_bingo  Bot_word_len  Player_word_len  \
# game_id
# 2                0.214286          4.25         3.428571
#
#          Bot_count_letters_JQXZ  Player_count_letters_JQXZ  \
# game_id
# 2                             3                          1
#
#          Bot_rack_used_rate  Player_rack_used_rate  Bot_win  Player_win  \
# game_id
# 2                  0.617063               0.623377        0           1
#
#          Bot_game  Player_game  Bot_score  Player_score  Bot_rating  \
# game_id
# 2            5383           42        401           488        2000
#
#          Player_rating           created_at  hist_player_performance  \
# game_id
# 2                  NaN  2022-08-10 19:19:59                   2052.9
#
#          Bot_Double_Word  Bot_Triple_Word  Bot_Double_Letter  \
# game_id
# 2                      6                2                  5
#
#          Bot_Triple_Letter  Player_Double_Word  Player_Triple_Word  \
# game_id
# 2                        6                   4                   5
#
#          Player_Double_Letter  Player_Triple_Letter
# game_id
# 2                           4                     3

# %%
df[df["Player_nickname"] == "Super"]
# Out:
#          game_id      first time_control_name game_end_reason lexicon  \
# game_id
# 62023      62023      Super           regular        STANDARD   CSW21
# 68925      68925  BetterBot           regular        STANDARD   CSW21
# 16923      16923      Super           regular        STANDARD   CSW21
# 56032      56032  BetterBot           regular        STANDARD   CSW21
# 5489        5489      Super           regular        STANDARD   CSW21
# ...          ...        ...               ...             ...     ...
# 45575      45575  BetterBot           regular        STANDARD   CSW21
# 67637      67637      Super           regular        STANDARD   CSW21
# 46667      46667  BetterBot           regular        STANDARD   CSW21
# 57437      57437      Super           regular        STANDARD   CSW21
# 8556        8556  BetterBot           regular        STANDARD   CSW21
#
#          initial_time_seconds  increment_seconds rating_mode  \
# game_id
# 62023                    3600                  0       RATED
# 68925                    3600                  0       RATED
# 16923                    3600                  0       RATED
# 56032                    3600                  0       RATED
# 5489                     3600                  0       RATED
# ...                       ...                ...         ...
# 45575                    3600                  0       RATED
# 67637                    3600                  0       RATED
# 46667                    3600                  0       RATED
# 57437                    3600                  0       RATED
# 8556                     3600                  0       RATED
#
#          max_overtime_minutes  game_duration_seconds Bot_nickname  \
# game_id
# 62023                       1             235.405642    BetterBot
# 68925                       1             263.150739    BetterBot
# 16923                       1             362.400079    BetterBot
# 56032                       1             194.923147    BetterBot
# 5489                        1             186.427055    BetterBot
# ...                       ...                    ...          ...
# 45575                       1             205.030277    BetterBot
# 67637                       1             208.947029    BetterBot
# 46667                       1             180.099339    BetterBot
# 57437                       1             179.065789    BetterBot
# 8556                        1             308.909205    BetterBot
#
#         Player_nickname  Bot_turns_count  Player_turns_count  Bot_max_point  \
# game_id
# 62023             Super               13                  13             66
# 68925             Super               13                  13             45
# 16923             Super               13                  13             76
# 56032             Super               14                  13             34
# 5489              Super               12                  12             86
# ...                 ...              ...                 ...            ...
# 45575             Super               13                  13             60
# 67637             Super               14                  14             74
# 46667             Super               14                  13             86
# 57437             Super               11                  11             83
# 8556              Super               13                  13             86
#
#          Player_max_point  Bot_min_point  Player_min_point  Bot_avg_bingo  \
# game_id
# 62023                  84              6                 6       0.142857
# 68925                  70             10                 0       0.000000
# 16923                  88              2                 5       0.071429
# 56032                  83             12                 5       0.000000
# 5489                   74              6                 7       0.153846
# ...                   ...            ...               ...            ...
# 45575                  94              8                 4       0.076923
# 67637                  79              2                 6       0.066667
# 46667                  90              4                 7       0.066667
# 57437                  76              6                13       0.166667
# 8556                   72              7                 2       0.076923
#
#          Player_avg_bingo  Bot_word_len  Player_word_len  \
# game_id
# 62023            0.076923      3.928571         3.230769
# 68925            0.071429      4.153846         3.214286
# 16923            0.153846      3.428571         3.923077
# 56032            0.153846      3.133333         3.692308
# 5489             0.166667      3.461538         4.083333
# ...                   ...           ...              ...
# 45575            0.142857      3.769231         3.428571
# 67637            0.142857      3.066667         3.785714
# 46667            0.076923      3.266667         3.769231
# 57437            0.272727      3.916667         4.636364
# 8556             0.142857      3.846154         3.500000
#
#          Bot_count_letters_JQXZ  Player_count_letters_JQXZ  \
# game_id
# 62023                         1                          3
# 68925                         3                          1
# 16923                         0                          4
# 56032                         2                          2
# 5489                          3                          1
# ...                         ...                        ...
# 45575                         2                          2
# 67637                         1                          3
# 46667                         1                          3
# 57437                         0                          4
# 8556                          2                          2
#
#          Bot_rack_used_rate  Player_rack_used_rate  Bot_win  Player_win  \
# game_id
# 62023              0.604396               0.461538        1           0
# 68925              0.628205               0.607143        1           0
# 16923              0.571429               0.585165        0           1
# 56032              0.530612               0.527473        0           1
# 5489               0.535714               0.583333        1           0
# ...                     ...                    ...      ...         ...
# 45575              0.547253               0.571429        0           1
# 67637              0.520408               0.557143        0           1
# 46667              0.561224               0.545788        0           1
# 57437              0.610390               0.662338        0           1
# 8556               0.574176               0.604396        0           1
#
#          Bot_game  Player_game  Bot_score  Player_score  Bot_rating  \
# game_id
# 62023        3040            1        419           365        2042
# 68925        3043            2        362           324        2057
# 16923        3044            3        338           448        2062
# 56032        3045            4        305           412        2056
# 5489         3048            5        408           403        2027
# ...           ...          ...        ...           ...         ...
# 45575       18850          136        402           418        1944
# 67637       18853          137        298           516        1935
# 46667       18854          138        348           426        1926
# 57437       18856          139        389           472        1917
# 8556        18858          140        356           406        1912
#
#          Player_rating           created_at  hist_player_performance  \
# game_id
# 62023              NaN  2022-08-05 20:48:09                   1700.0
# 68925              NaN  2022-08-05 20:52:09                   1694.2
# 16923              NaN  2022-08-05 20:56:36                   1689.9
# 56032              NaN  2022-08-05 21:02:44                   1766.1
# 5489               NaN  2022-08-05 21:06:03                   1841.7
# ...                ...                  ...                      ...
# 45575              NaN  2022-09-11 01:46:19                   2146.9
# 67637              NaN  2022-09-11 01:49:48                   2140.1
# 46667              NaN  2022-09-11 01:53:24                   2213.7
# 57437              NaN  2022-09-11 01:56:31                   2205.6
# 8556               NaN  2022-09-11 01:59:41                   2197.5
#
#          Bot_Double_Word  Bot_Triple_Word  Bot_Double_Letter  \
# game_id
# 62023                  3                3                  7
# 68925                  7                1                  7
# 16923                  6                2                  5
# 56032                  5                1                  8
# 5489                   3                2                  4
# ...                  ...              ...                ...
# 45575                  5                3                  9
# 67637                  4                3                  8
# 46667                  5                4                  6
# 57437                  4                5                  4
# 8556                   1                5                  9
#
#          Bot_Triple_Letter  Player_Double_Word  Player_Triple_Word  \
# game_id
# 62023                    6                   6                   2
# 68925                    4                   5                   4
# 16923                    2                   5                   3
# 56032                    4                   3                   4
# 5489                     7                   3                   3
# ...                    ...                 ...                 ...
# 45575                    1                   8                   1
# 67637                    3                   4                   4
# 46667                    2                   8                   2
# 57437                    3                   5                   2
# 8556                     5                   8                   2
#
#          Player_Double_Letter  Player_Triple_Letter
# game_id
# 62023                       2                     4
# 68925                       4                     1
# 16923                       4                     5
# 56032                       8                     3
# 5489                        9                     4
# ...                       ...                   ...
# 45575                       3                     4
# 67637                       6                     5
# 46667                       5                     3
# 57437                       5                     4
# 8556                        4                     2
#
# [140 rows x 44 columns]

# %%
df[df["game_id"] == 62023]
# Out:
#          game_id  first time_control_name game_end_reason lexicon  \
# game_id
# 62023      62023  Super           regular        STANDARD   CSW21
#
#          initial_time_seconds  increment_seconds rating_mode  \
# game_id
# 62023                    3600                  0       RATED
#
#          max_overtime_minutes  game_duration_seconds Bot_nickname  \
# game_id
# 62023                       1             235.405642    BetterBot
#
#         Player_nickname  Bot_turns_count  Player_turns_count  Bot_max_point  \
# game_id
# 62023             Super               13                  13             66
#
#          Player_max_point  Bot_min_point  Player_min_point  Bot_avg_bingo  \
# game_id
# 62023                  84              6                 6       0.142857
#
#          Player_avg_bingo  Bot_word_len  Player_word_len  \
# game_id
# 62023            0.076923      3.928571         3.230769
#
#          Bot_count_letters_JQXZ  Player_count_letters_JQXZ  \
# game_id
# 62023                         1                          3
#
#          Bot_rack_used_rate  Player_rack_used_rate  Bot_win  Player_win  \
# game_id
# 62023              0.604396               0.461538        1           0
#
#          Bot_game  Player_game  Bot_score  Player_score  Bot_rating  \
# game_id
# 62023        3040            1        419           365        2042
#
#          Player_rating           created_at  hist_player_performance  \
# game_id
# 62023              NaN  2022-08-05 20:48:09                   1700.0
#
#          Bot_Double_Word  Bot_Triple_Word  Bot_Double_Letter  \
# game_id
# 62023                  3                3                  7
#
#          Bot_Triple_Letter  Player_Double_Word  Player_Triple_Word  \
# game_id
# 62023                    6                   6                   2
#
#          Player_Double_Letter  Player_Triple_Letter
# game_id
# 62023                       2                     4

# %%
df.columns
# Out:
# Index(['game_id', 'first', 'time_control_name', 'game_end_reason', 'lexicon',
#        'initial_time_seconds', 'increment_seconds', 'rating_mode',
#        'max_overtime_minutes', 'game_duration_seconds', 'Bot_nickname',
#        'Player_nickname', 'Bot_turns_count', 'Player_turns_count',
#        'Bot_max_point', 'Player_max_point', 'Bot_min_point',
#        'Player_min_point', 'Bot_avg_bingo', 'Player_avg_bingo', 'Bot_word_len',
#        'Player_word_len', 'Bot_count_letters_JQXZ',
#        'Player_count_letters_JQXZ', 'Bot_rack_used_rate',
#        'Player_rack_used_rate', 'Bot_win', 'Player_win', 'Bot_game',
#        'Player_game', 'Bot_score', 'Player_score', 'Bot_rating',
#        'Player_rating', 'created_at', 'hist_player_performance',
#        'Bot_Double_Word', 'Bot_Triple_Word', 'Bot_Double_Letter',
#        'Bot_Triple_Letter', 'Player_Double_Word', 'Player_Triple_Word',
#        'Player_Double_Letter', 'Player_Triple_Letter'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# game_id                          0
# first                            0
# time_control_name                0
# game_end_reason                  0
# lexicon                          0
# initial_time_seconds             0
# increment_seconds                0
# rating_mode                      0
# max_overtime_minutes             0
# game_duration_seconds            0
# Bot_nickname                     0
# Player_nickname                  0
# Bot_turns_count                  0
# Player_turns_count               0
# Bot_max_point                    0
# Player_max_point                 0
# Bot_min_point                    0
# Player_min_point                 0
# Bot_avg_bingo                    0
# Player_avg_bingo                 0
# Bot_word_len                     0
# Player_word_len                  0
# Bot_count_letters_JQXZ           0
# Player_count_letters_JQXZ        0
# Bot_rack_used_rate               0
# Player_rack_used_rate            0
# Bot_win                          0
# Player_win                       0
# Bot_game                         0
# Player_game                      0
# Bot_score                        0
# Player_score                     0
# Bot_rating                       0
# Player_rating                22363
# created_at                       0
# hist_player_performance          0
# Bot_Double_Word                  0
# Bot_Triple_Word                  0
# Bot_Double_Letter                0
# Bot_Triple_Letter                0
# Player_Double_Word               0
# Player_Triple_Word               0
# Player_Double_Letter             0
# Player_Triple_Letter             0
# dtype: int64

# %%
df.dtypes
# Out:
# game_id                        int64
# first                         object
# time_control_name             object
# game_end_reason               object
# lexicon                       object
# initial_time_seconds           int64
# increment_seconds              int64
# rating_mode                   object
# max_overtime_minutes           int64
# game_duration_seconds        float64
# Bot_nickname                  object
# Player_nickname               object
# Bot_turns_count                int64
# Player_turns_count             int64
# Bot_max_point                  int64
# Player_max_point               int64
# Bot_min_point                  int64
# Player_min_point               int64
# Bot_avg_bingo                float64
# Player_avg_bingo             float64
# Bot_word_len                 float64
# Player_word_len              float64
# Bot_count_letters_JQXZ         int64
# Player_count_letters_JQXZ      int64
# Bot_rack_used_rate           float64
# Player_rack_used_rate        float64
# Bot_win                        int64
# Player_win                     int64
# Bot_game                       int64
# Player_game                    int64
# Bot_score                      int64
# Player_score                   int64
# Bot_rating                     int64
# Player_rating                float64
# created_at                    object
# hist_player_performance      float64
# Bot_Double_Word                int64
# Bot_Triple_Word                int64
# Bot_Double_Letter              int64
# Bot_Triple_Letter              int64
# Player_Double_Word             int64
# Player_Triple_Word             int64
# Player_Double_Letter           int64
# Player_Triple_Letter           int64
# dtype: object

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# Drop 'game_id'
df = df.drop('game_id', axis=1)

# Set binary column based on 'first' values
df['first_bot'] = df['first'].isin(["HastyBot", "BetterBot", "STEEBot"]).astype(int)
df = df.drop('first', axis=1)

# One-hot encode categorical columns
categorical_columns = ['time_control_name', 'game_end_reason', 'lexicon', 'rating_mode', 'Bot_nickname']
df = pd.get_dummies(df, columns=categorical_columns)

# Drop 'Player_nickname' and 'created_at'
df = df.drop(['Player_nickname', 'created_at', "Bot_game"], axis=1)

# Move 'Player_rating' to the last column
cols = [col for col in df.columns if col != 'Player_rating'] + ['Player_rating']
df = df[cols]

df
# Out:
#          initial_time_seconds  increment_seconds  max_overtime_minutes  \
# game_id
# 43828                      15                  0                     1
# 5765                     1200                  0                     1
# 40264                    1200                  0                     1
# 44376                    1200                  0                     1
# 32633                    1200                  0                     1
# ...                       ...                ...                   ...
# 7264                     1200                  0                     1
# 66022                    1380                  0                     1
# 2581                     1380                  0                     1
# 54204                    1200                  0                     1
# 23789                    1200                  0                     1
#
#          game_duration_seconds  Bot_turns_count  Player_turns_count  \
# game_id
# 43828                61.405180               16                  16
# 5765               1268.252752               11                  12
# 40264              1262.786704               12                  12
# 44376              1209.746654               15                  16
# 32633              1231.166683               15                  16
# ...                        ...              ...                 ...
# 7264                683.258274               13                  14
# 66022               626.274697               13                  13
# 2581                775.765387               12                  11
# 54204               624.940244               14                  14
# 23789               589.657785               12                  13
#
#          Bot_max_point  Player_max_point  Bot_min_point  Player_min_point  \
# game_id
# 43828               72                14              0               -10
# 5765                92                35             16               -10
# 40264               74                36              8               -10
# 44376              102                75              8               -10
# 32633               85                85              6               -10
# ...                ...               ...            ...               ...
# 7264                77                78             10                 0
# 66022               78                66              0                 0
# 2581                70                76             13                17
# 54204               70                73              0                 0
# 23789               71                92              9                 2
#
#          Bot_avg_bingo  Player_avg_bingo  Bot_word_len  Player_word_len  \
# game_id
# 43828         0.062500          0.000000      4.187500         0.312500
# 5765          0.272727          0.000000      4.090909         2.250000
# 40264         0.166667          0.000000      4.166667         3.000000
# 44376         0.125000          0.062500      3.750000         2.437500
# 32633         0.066667          0.117647      3.400000         2.823529
# ...                ...               ...           ...              ...
# 7264          0.076923          0.066667      3.846154         3.200000
# 66022         0.142857          0.076923      3.285714         3.846154
# 2581          0.076923          0.181818      3.923077         4.000000
# 54204         0.000000          0.133333      3.571429         3.200000
# 23789         0.083333          0.071429      3.916667         3.714286
#
#          Bot_count_letters_JQXZ  Player_count_letters_JQXZ  \
# game_id
# 43828                         2                          0
# 5765                          4                          0
# 40264                         0                          2
# 44376                         4                          0
# 32633                         3                          1
# ...                         ...                        ...
# 7264                          3                          1
# 66022                         3                          1
# 2581                          3                          1
# 54204                         2                          2
# 23789                         3                          1
#
#          Bot_rack_used_rate  Player_rack_used_rate  Bot_win  Player_win  \
# game_id
# 43828              0.638095               0.178571        1           0
# 5765               0.584416               0.482143        1           0
# 40264              0.595238               0.467532        1           0
# 44376              0.625397               0.396825        1           0
# 32633              0.520952               0.519048        0           1
# ...                     ...                    ...      ...         ...
# 7264               0.549451               0.538462        1           0
# 66022              0.649351               0.595238        1           0
# 2581               0.642857               0.571429        0           1
# 54204              0.565934               0.582418        0           1
# 23789              0.559524               0.637363        0           1
#
#          Player_game  Bot_score  Player_score  Bot_rating  \
# game_id
# 43828              1        472            15        2148
# 5765               1        462           141        2012
# 40264              2        356           212        1966
# 44376              3        535           227        2090
# 32633              4        383           391        2114
# ...              ...        ...           ...         ...
# 7264               7        414           327        2231
# 66022              1        393           357        1859
# 2581               2        358           438        1863
# 54204              3        357           412        1856
# 23789              4        362           391        1838
#
#          hist_player_performance  Bot_Double_Word  Bot_Triple_Word  \
# game_id
# 43828                     1700.0                4                5
# 5765                      1700.0                2                3
# 40264                     1691.2                7                0
# 44376                     1677.8                6                4
# 32633                     1676.8                7                1
# ...                          ...              ...              ...
# 7264                      1750.7                5                2
# 66022                     1700.0                5                1
# 2581                      1675.9                5                2
# 54204                     1732.2                6                3
# 23789                     1787.8                6                2
#
#          Bot_Double_Letter  Bot_Triple_Letter  Player_Double_Word  \
# game_id
# 43828                    8                  4                   0
# 5765                     7                  5                   4
# 40264                    4                  6                   3
# 44376                    9                  5                   4
# 32633                    6                  5                   6
# ...                    ...                ...                 ...
# 7264                     5                  4                   5
# 66022                    5                  2                   6
# 2581                     6                  5                   3
# 54204                    5                  4                   9
# 23789                    3                  5                   5
#
#          Player_Triple_Word  Player_Double_Letter  Player_Triple_Letter  \
# game_id
# 43828                     0                     1                     1
# 5765                      2                     3                     0
# 40264                     4                     5                     5
# 44376                     3                     9                     0
# 32633                     5                     4                     2
# ...                     ...                   ...                   ...
# 7264                      5                     4                     1
# 66022                     3                     4                     1
# 2581                      4                     6                     5
# 54204                     1                     5                     4
# 23789                     5                     6                     3
#
#          first_bot  time_control_name_blitz  time_control_name_rapid  \
# game_id
# 43828            1                        0                        0
# 5765             0                        0                        0
# 40264            1                        0                        0
# 44376            0                        0                        0
# 32633            1                        0                        0
# ...            ...                      ...                      ...
# 7264             0                        0                        0
# 66022            0                        0                        0
# 2581             1                        0                        0
# 54204            1                        0                        0
# 23789            0                        0                        0
#
#          time_control_name_regular  time_control_name_ultrablitz  \
# game_id
# 43828                            0                             1
# 5765                             1                             0
# 40264                            1                             0
# 44376                            1                             0
# 32633                            1                             0
# ...                            ...                           ...
# 7264                             1                             0
# 66022                            1                             0
# 2581                             1                             0
# 54204                            1                             0
# 23789                            1                             0
#
#          game_end_reason_CONSECUTIVE_ZEROES  game_end_reason_RESIGNED  \
# game_id
# 43828                                     0                         1
# 5765                                      0                         0
# 40264                                     0                         0
# 44376                                     0                         0
# 32633                                     0                         0
# ...                                     ...                       ...
# 7264                                      0                         0
# 66022                                     0                         0
# 2581                                      0                         0
# 54204                                     0                         0
# 23789                                     0                         0
#
#          game_end_reason_STANDARD  game_end_reason_TIME  lexicon_CSW21  \
# game_id
# 43828                           0                     0              1
# 5765                            0                     1              1
# 40264                           0                     1              1
# 44376                           1                     0              1
# 32633                           1                     0              1
# ...                           ...                   ...            ...
# 7264                            1                     0              1
# 66022                           1                     0              0
# 2581                            1                     0              0
# 54204                           1                     0              0
# 23789                           1                     0              0
#
#          lexicon_ECWL  lexicon_NSWL20  lexicon_NWL20  rating_mode_CASUAL  \
# game_id
# 43828               0               0              0                   0
# 5765                0               0              0                   0
# 40264               0               0              0                   0
# 44376               0               0              0                   0
# 32633               0               0              0                   0
# ...               ...             ...            ...                 ...
# 7264                0               0              0                   0
# 66022               0               0              1                   0
# 2581                0               0              1                   0
# 54204               0               0              1                   0
# 23789               0               0              1                   0
#
#          rating_mode_RATED  Bot_nickname_BetterBot  Bot_nickname_HastyBot  \
# game_id
# 43828                    1                       0                      1
# 5765                     1                       1                      0
# 40264                    1                       1                      0
# 44376                    1                       1                      0
# 32633                    1                       1                      0
# ...                    ...                     ...                    ...
# 7264                     1                       0                      1
# 66022                    1                       0                      0
# 2581                     1                       0                      0
# 54204                    1                       0                      0
# 23789                    1                       0                      0
#
#          Bot_nickname_STEEBot  Player_rating
# game_id
# 43828                       0         1979.0
# 5765                        0         1447.0
# 40264                       0         1408.0
# 44376                       0         1372.0
# 32633                       0         1367.0
# ...                       ...            ...
# 7264                        0         1855.0
# 66022                       1         1641.0
# 2581                        1         1637.0
# 54204                       1         1626.0
# 23789                       1         1641.0
#
# [72773 rows x 52 columns]

# %%
df.columns
# Out:
# Index(['initial_time_seconds', 'increment_seconds', 'max_overtime_minutes',
#        'game_duration_seconds', 'Bot_turns_count', 'Player_turns_count',
#        'Bot_max_point', 'Player_max_point', 'Bot_min_point',
#        'Player_min_point', 'Bot_avg_bingo', 'Player_avg_bingo', 'Bot_word_len',
#        'Player_word_len', 'Bot_count_letters_JQXZ',
#        'Player_count_letters_JQXZ', 'Bot_rack_used_rate',
#        'Player_rack_used_rate', 'Bot_win', 'Player_win', 'Player_game',
#        'Bot_score', 'Player_score', 'Bot_rating', 'hist_player_performance',
#        'Bot_Double_Word', 'Bot_Triple_Word', 'Bot_Double_Letter',
#        'Bot_Triple_Letter', 'Player_Double_Word', 'Player_Triple_Word',
#        'Player_Double_Letter', 'Player_Triple_Letter', 'first_bot',
#        'time_control_name_blitz', 'time_control_name_rapid',
#        'time_control_name_regular', 'time_control_name_ultrablitz',
#        'game_end_reason_CONSECUTIVE_ZEROES', 'game_end_reason_RESIGNED',
#        'game_end_reason_STANDARD', 'game_end_reason_TIME', 'lexicon_CSW21',
#        'lexicon_ECWL', 'lexicon_NSWL20', 'lexicon_NWL20', 'rating_mode_CASUAL',
#        'rating_mode_RATED', 'Bot_nickname_BetterBot', 'Bot_nickname_HastyBot',
#        'Bot_nickname_STEEBot', 'Player_rating'],
#       dtype='object')

# %%
df.dtypes
# Out:
# initial_time_seconds                    int64
# increment_seconds                       int64
# max_overtime_minutes                    int64
# game_duration_seconds                 float64
# Bot_turns_count                         int64
# Player_turns_count                      int64
# Bot_max_point                           int64
# Player_max_point                        int64
# Bot_min_point                           int64
# Player_min_point                        int64
# Bot_avg_bingo                         float64
# Player_avg_bingo                      float64
# Bot_word_len                          float64
# Player_word_len                       float64
# Bot_count_letters_JQXZ                  int64
# Player_count_letters_JQXZ               int64
# Bot_rack_used_rate                    float64
# Player_rack_used_rate                 float64
# Bot_win                                 int64
# Player_win                              int64
# Player_game                             int64
# Bot_score                               int64
# Player_score                            int64
# Bot_rating                              int64
# hist_player_performance               float64
# Bot_Double_Word                         int64
# Bot_Triple_Word                         int64
# Bot_Double_Letter                       int64
# Bot_Triple_Letter                       int64
# Player_Double_Word                      int64
# Player_Triple_Word                      int64
# Player_Double_Letter                    int64
# Player_Triple_Letter                    int64
# first_bot                               int32
# time_control_name_blitz                 uint8
# time_control_name_rapid                 uint8
# time_control_name_regular               uint8
# time_control_name_ultrablitz            uint8
# game_end_reason_CONSECUTIVE_ZEROES      uint8
# game_end_reason_RESIGNED                uint8
# game_end_reason_STANDARD                uint8
# game_end_reason_TIME                    uint8
# lexicon_CSW21                           uint8
# lexicon_ECWL                            uint8
# lexicon_NSWL20                          uint8
# lexicon_NWL20                           uint8
# rating_mode_CASUAL                      uint8
# rating_mode_RATED                       uint8
# Bot_nickname_BetterBot                  uint8
# Bot_nickname_HastyBot                   uint8
# Bot_nickname_STEEBot                    uint8
# Player_rating                         float64
# dtype: object

# %%
train = df[df["Player_rating"].isnull()==False]
test = df[df["Player_rating"].isnull()==True]

# %%
df = train

# %%
df.shape
# Out:
# (50410, 52)

# %%
from sklearn.ensemble import RandomForestRegressor
import numpy as np

# Assuming df is your DataFrame
X = df.drop('Player_rating', axis=1)  # Features
y = df['Player_rating']  # Target variable

# Initialize the Random Forest Regressor
rf_model = RandomForestRegressor(random_state=42)

# Fit the model to the data
rf_model.fit(X, y)

# Get feature importances
feature_importances = rf_model.feature_importances_

# Create a DataFrame to store the results
feature_importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': feature_importances
})

# Sort the DataFrame by importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Print the sorted DataFrame
print(feature_importance_df)
# Out:
#                                Feature  Importance
# 24             hist_player_performance    0.599640
# 23                          Bot_rating    0.114464
# 22                        Player_score    0.031844
# 20                         Player_game    0.030791
# 0                 initial_time_seconds    0.027330
# 3                game_duration_seconds    0.025171
# 17               Player_rack_used_rate    0.016176
# 46                  rating_mode_CASUAL    0.013640
# 47                   rating_mode_RATED    0.012899
# 13                     Player_word_len    0.009100
# 49               Bot_nickname_HastyBot    0.008761
# 42                       lexicon_CSW21    0.008617
# 2                 max_overtime_minutes    0.007944
# 21                           Bot_score    0.006948
# 7                     Player_max_point    0.006519
# 9                     Player_min_point    0.006463
# 43                        lexicon_ECWL    0.005904
# 16                  Bot_rack_used_rate    0.005013
# 6                        Bot_max_point    0.004807
# 12                        Bot_word_len    0.004404
# 45                       lexicon_NWL20    0.004229
# 8                        Bot_min_point    0.003765
# 11                    Player_avg_bingo    0.003520
# 10                       Bot_avg_bingo    0.003051
# 27                   Bot_Double_Letter    0.002971
# 31                Player_Double_Letter    0.002955
# 29                  Player_Double_Word    0.002805
# 30                  Player_Triple_Word    0.002801
# 28                   Bot_Triple_Letter    0.002680
# 25                     Bot_Double_Word    0.002650
# 32                Player_Triple_Letter    0.002381
# 35             time_control_name_rapid    0.002376
# 5                   Player_turns_count    0.002274
# 26                     Bot_Triple_Word    0.002206
# 4                      Bot_turns_count    0.001914
# 48              Bot_nickname_BetterBot    0.001781
# 50                Bot_nickname_STEEBot    0.001467
# 14              Bot_count_letters_JQXZ    0.001377
# 15           Player_count_letters_JQXZ    0.001298
# 36           time_control_name_regular    0.001192
# 1                    increment_seconds    0.000836
# 33                           first_bot    0.000581
# 39            game_end_reason_RESIGNED    0.000571
# 34             time_control_name_blitz    0.000508
# 40            game_end_reason_STANDARD    0.000386
# 37        time_control_name_ultrablitz    0.000326
# 41                game_end_reason_TIME    0.000242
# 19                          Player_win    0.000211
# 18                             Bot_win    0.000190
# 38  game_end_reason_CONSECUTIVE_ZEROES    0.000018
# 44                      lexicon_NSWL20    0.000001

# %%
selected_features = feature_importance_df[feature_importance_df['Importance'] > 0.005]

# Sort the DataFrame by importance in descending order
selected_features = selected_features.sort_values(by='Importance', ascending=False)

# Print the sorted DataFrame
selected_features
# Out:
#                     Feature  Importance
# 24  hist_player_performance    0.599640
# 23               Bot_rating    0.114464
# 22             Player_score    0.031844
# 20              Player_game    0.030791
# 0      initial_time_seconds    0.027330
# 3     game_duration_seconds    0.025171
# 17    Player_rack_used_rate    0.016176
# 46       rating_mode_CASUAL    0.013640
# 47        rating_mode_RATED    0.012899
# 13          Player_word_len    0.009100
# 49    Bot_nickname_HastyBot    0.008761
# 42            lexicon_CSW21    0.008617
# 2      max_overtime_minutes    0.007944
# 21                Bot_score    0.006948
# 7          Player_max_point    0.006519
# 9          Player_min_point    0.006463
# 43             lexicon_ECWL    0.005904
# 16       Bot_rack_used_rate    0.005013

# %%
# Assuming df is your original DataFrame
selected_feature_names = selected_features['Feature'].tolist()

# Select columns with the important features
df_selected = df[selected_feature_names + ['Player_rating']]

# Display the selected DataFrame
df_selected.head()
# Out:
#          hist_player_performance  Bot_rating  Player_score  Player_game  \
# game_id
# 43828                     1700.0        2148            15            1
# 5765                      1700.0        2012           141            1
# 40264                     1691.2        1966           212            2
# 44376                     1677.8        2090           227            3
# 32633                     1676.8        2114           391            4
#
#          initial_time_seconds  game_duration_seconds  Player_rack_used_rate  \
# game_id
# 43828                      15              61.405180               0.178571
# 5765                     1200            1268.252752               0.482143
# 40264                    1200            1262.786704               0.467532
# 44376                    1200            1209.746654               0.396825
# 32633                    1200            1231.166683               0.519048
#
#          rating_mode_CASUAL  rating_mode_RATED  Player_word_len  \
# game_id
# 43828                     0                  1         0.312500
# 5765                      0                  1         2.250000
# 40264                     0                  1         3.000000
# 44376                     0                  1         2.437500
# 32633                     0                  1         2.823529
#
#          Bot_nickname_HastyBot  lexicon_CSW21  max_overtime_minutes  \
# game_id
# 43828                        1              1                     1
# 5765                         0              1                     1
# 40264                        0              1                     1
# 44376                        0              1                     1
# 32633                        0              1                     1
#
#          Bot_score  Player_max_point  Player_min_point  lexicon_ECWL  \
# game_id
# 43828          472                14               -10             0
# 5765           462                35               -10             0
# 40264          356                36               -10             0
# 44376          535                75               -10             0
# 32633          383                85               -10             0
#
#          Bot_rack_used_rate  Player_rating
# game_id
# 43828              0.638095         1979.0
# 5765               0.584416         1447.0
# 40264              0.595238         1408.0
# 44376              0.625397         1372.0
# 32633              0.520952         1367.0

# %%
df_selected
# Out:
#          hist_player_performance  Bot_rating  Player_score  Player_game  \
# game_id
# 43828                     1700.0        2148            15            1
# 5765                      1700.0        2012           141            1
# 40264                     1691.2        1966           212            2
# 44376                     1677.8        2090           227            3
# 32633                     1676.8        2114           391            4
# ...                          ...         ...           ...          ...
# 7264                      1750.7        2231           327            7
# 66022                     1700.0        1859           357            1
# 2581                      1675.9        1863           438            2
# 54204                     1732.2        1856           412            3
# 23789                     1787.8        1838           391            4
#
#          initial_time_seconds  game_duration_seconds  Player_rack_used_rate  \
# game_id
# 43828                      15              61.405180               0.178571
# 5765                     1200            1268.252752               0.482143
# 40264                    1200            1262.786704               0.467532
# 44376                    1200            1209.746654               0.396825
# 32633                    1200            1231.166683               0.519048
# ...                       ...                    ...                    ...
# 7264                     1200             683.258274               0.538462
# 66022                    1380             626.274697               0.595238
# 2581                     1380             775.765387               0.571429
# 54204                    1200             624.940244               0.582418
# 23789                    1200             589.657785               0.637363
#
#          rating_mode_CASUAL  rating_mode_RATED  Player_word_len  \
# game_id
# 43828                     0                  1         0.312500
# 5765                      0                  1         2.250000
# 40264                     0                  1         3.000000
# 44376                     0                  1         2.437500
# 32633                     0                  1         2.823529
# ...                     ...                ...              ...
# 7264                      0                  1         3.200000
# 66022                     0                  1         3.846154
# 2581                      0                  1         4.000000
# 54204                     0                  1         3.200000
# 23789                     0                  1         3.714286
#
#          Bot_nickname_HastyBot  lexicon_CSW21  max_overtime_minutes  \
# game_id
# 43828                        1              1                     1
# 5765                         0              1                     1
# 40264                        0              1                     1
# 44376                        0              1                     1
# 32633                        0              1                     1
# ...                        ...            ...                   ...
# 7264                         1              1                     1
# 66022                        0              0                     1
# 2581                         0              0                     1
# 54204                        0              0                     1
# 23789                        0              0                     1
#
#          Bot_score  Player_max_point  Player_min_point  lexicon_ECWL  \
# game_id
# 43828          472                14               -10             0
# 5765           462                35               -10             0
# 40264          356                36               -10             0
# 44376          535                75               -10             0
# 32633          383                85               -10             0
# ...            ...               ...               ...           ...
# 7264           414                78                 0             0
# 66022          393                66                 0             0
# 2581           358                76                17             0
# 54204          357                73                 0             0
# 23789          362                92                 2             0
#
#          Bot_rack_used_rate  Player_rating
# game_id
# 43828              0.638095         1979.0
# 5765               0.584416         1447.0
# 40264              0.595238         1408.0
# 44376              0.625397         1372.0
# 32633              0.520952         1367.0
# ...                     ...            ...
# 7264               0.549451         1855.0
# 66022              0.649351         1641.0
# 2581               0.642857         1637.0
# 54204              0.565934         1626.0
# 23789              0.559524         1641.0
#
# [50410 rows x 19 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold
from sklearn.metrics import make_scorer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
import numpy as np

# Assuming df_selected is your DataFrame
X = df_selected.drop('Player_rating', axis=1)
y = df_selected['Player_rating']

# Create a pipeline with a RandomForestRegressor
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('rf', RandomForestRegressor())
])

# Define parameter grid for grid search
param_grid = {
    'rf__n_estimators': [50, 100, 200],
    'rf__max_depth': [None, 8, 15, 20],
    'rf__min_samples_split': [2, 5, 10],
    'rf__min_samples_leaf': [1, 2, 4]
}

# Define RMSE as the scoring metric for GridSearchCV
rmse_scorer = make_scorer(lambda y_true, y_pred: np.sqrt(np.mean((y_true - y_pred)**2)))

# Initialize GridSearchCV
grid_search = GridSearchCV(pipeline, param_grid, cv=10, scoring=rmse_scorer, n_jobs=-1)

# Fit the model
grid_search.fit(X, y)

# Get the best parameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)

# Get the best model
best_model = grid_search.best_estimator_
print("Best Model:", best_model)

# Get cross-validation scores
print("Running cross-validation. This may take some time...")
kf = KFold(n_splits=10, shuffle=True, random_state=42)  # Specify the same number of splits as the GridSearchCV
fold = 1
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    best_model.fit(X_train, y_train)
    y_pred = best_model.predict(X_test)

    fold_rmse = np.sqrt(np.mean((y_test - y_pred)**2))
    print(f"Fold {fold}: RMSE = {fold_rmse}")
    fold += 1
# Out:
# Best Parameters: {'rf__max_depth': 8, 'rf__min_samples_leaf': 1, 'rf__min_samples_split': 5, 'rf__n_estimators': 50}
# Best Model: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('rf',
#                  RandomForestRegressor(max_depth=8, min_samples_split=5,
#                                        n_estimators=50))])
# Running cross-validation. This may take some time...
# Fold 1: RMSE = 97.05437358617313
# Fold 2: RMSE = 96.37362662351852
# Fold 3: RMSE = 98.97253912266281
# Fold 4: RMSE = 96.07544522016947
# Fold 5: RMSE = 94.90364750200062
# Fold 6: RMSE = 95.81950416165516
# Fold 7: RMSE = 97.6224792279071
# Fold 8: RMSE = 98.74582447014328
# Fold 9: RMSE = 97.26789573809042
# Fold 10: RMSE = 97.67960894800235

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold
from sklearn.metrics import make_scorer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
import numpy as np

# Assuming df_selected is your DataFrame
X = df_selected.drop('Player_rating', axis=1)
y = df_selected['Player_rating']

# Create a pipeline with a RandomForestRegressor
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('rf', RandomForestRegressor())
])

# Define parameter grid for grid search
param_grid = {
    'rf__n_estimators': [50],
    'rf__max_depth': [8],
    'rf__min_samples_split': [5],
    'rf__min_samples_leaf': [1]
}

# Define RMSE as the scoring metric for GridSearchCV
rmse_scorer = make_scorer(lambda y_true, y_pred: np.sqrt(np.mean((y_true - y_pred)**2)))

# Initialize GridSearchCV
grid_search = GridSearchCV(pipeline, param_grid, cv=10, scoring=rmse_scorer, n_jobs=-1)

# Fit the model
grid_search.fit(X, y)

# Get the best parameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)

# Get the best model
best_model = grid_search.best_estimator_
print("Best Model:", best_model)

# Get cross-validation scores
print("Running cross-validation. This may take some time...")
kf = KFold(n_splits=10, shuffle=True, random_state=42)  # Specify the same number of splits as the GridSearchCV
fold = 1
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    best_model.fit(X_train, y_train)
    y_pred = best_model.predict(X_test)

    fold_rmse = np.sqrt(np.mean((y_test - y_pred)**2))
    print(f"Fold {fold}: RMSE = {fold_rmse}")
    fold += 1
# Out:
# Best Parameters: {'rf__max_depth': 8, 'rf__min_samples_leaf': 1, 'rf__min_samples_split': 5, 'rf__n_estimators': 50}
# Best Model: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('rf',
#                  RandomForestRegressor(max_depth=8, min_samples_split=5,
#                                        n_estimators=50))])
# Running cross-validation. This may take some time...
# Fold 1: RMSE = 97.19774495938533
# Fold 2: RMSE = 96.7780849796144
# Fold 3: RMSE = 98.45841273039836
# Fold 4: RMSE = 96.66124651454379
# Fold 5: RMSE = 95.21534326456285
# Fold 6: RMSE = 95.05902744673278
# Fold 7: RMSE = 97.71330829527808
# Fold 8: RMSE = 99.0833431650744
# Fold 9: RMSE = 97.12302703485175
# Fold 10: RMSE = 97.91315507152076

# %%
test_df_selected = test[selected_feature_names + ['Player_rating']]

# Display the selected DataFrame
test_df_selected.head()
# Assuming df_selected is your DataFrame
test_X = test_df_selected.drop('Player_rating', axis=1)
test_y = test_df_selected['Player_rating']

# %%
test_X
# Out:
#          hist_player_performance  Bot_rating  Player_score  Player_game  \
# game_id
# 51857                     1700.0        1990           331            1
# 31730                     1700.0        2269           118            1
# 50150                     1716.9        2220           135            2
# 18710                     1700.0        2065           274            1
# 46342                     1696.5        2065           332            2
# ...                          ...         ...           ...          ...
# 5506                      2133.3        2218           366           44
# 26454                     2056.9        2222           348           45
# 14102                     2060.3        2235           341           46
# 69347                     2064.5        2261           460           47
# 65472                     2070.7        2235           384           48
#
#          initial_time_seconds  game_duration_seconds  Player_rack_used_rate  \
# game_id
# 51857                    1200             632.083319               0.397959
# 31730                    1200             256.453327               0.236395
# 50150                    1200             245.164982               0.253501
# 18710                     780             798.728617               0.428571
# 46342                     780             841.983634               0.590110
# ...                       ...                    ...                    ...
# 5506                      900             471.077622               0.523810
# 26454                     900             421.667981               0.559524
# 14102                     900             295.437074               0.516484
# 69347                     900             248.825438               0.571429
# 65472                     900             582.157926               0.565476
#
#          rating_mode_CASUAL  rating_mode_RATED  Player_word_len  \
# game_id
# 51857                     0                  1         2.785714
# 31730                     0                  1         1.642857
# 50150                     0                  1         1.764706
# 18710                     1                  0         2.785714
# 46342                     1                  0         3.333333
# ...                     ...                ...              ...
# 5506                      0                  1         3.666667
# 26454                     0                  1         3.916667
# 14102                     0                  1         3.071429
# 69347                     0                  1         3.666667
# 65472                     0                  1         3.833333
#
#          Bot_nickname_HastyBot  lexicon_CSW21  max_overtime_minutes  \
# game_id
# 51857                        0              1                     1
# 31730                        1              1                     1
# 50150                        1              1                     1
# 18710                        0              1                     1
# 46342                        0              1                     1
# ...                        ...            ...                   ...
# 5506                         1              1                     1
# 26454                        1              1                     1
# 14102                        1              1                     1
# 69347                        1              1                     1
# 65472                        1              1                     1
#
#          Bot_score  Player_max_point  Player_min_point  lexicon_ECWL  \
# game_id
# 51857          416                93                 6             0
# 31730          646                12                 2             0
# 50150          592                24                 2             0
# 18710          548                31               -10             0
# 46342          467                72               -29             0
# ...            ...               ...               ...           ...
# 5506           494                77                 4             0
# 26454          500                71                 4             0
# 14102          587                72                 4             0
# 69347          496                87                 0             0
# 65472          397                66                 9             0
#
#          Bot_rack_used_rate
# game_id
# 51857              0.561905
# 31730              0.723810
# 50150              0.615546
# 18710              0.670330
# 46342              0.629252
# ...                     ...
# 5506               0.648352
# 26454              0.607143
# 14102              0.617582
# 69347              0.607143
# 65472              0.624176
#
# [22363 rows x 18 columns]

# %%
test_X["Predictions"] = best_model.predict(test_X)

# %%
test_X
# Out:
#          hist_player_performance  Bot_rating  Player_score  Player_game  \
# game_id
# 51857                     1700.0        1990           331            1
# 31730                     1700.0        2269           118            1
# 50150                     1716.9        2220           135            2
# 18710                     1700.0        2065           274            1
# 46342                     1696.5        2065           332            2
# ...                          ...         ...           ...          ...
# 5506                      2133.3        2218           366           44
# 26454                     2056.9        2222           348           45
# 14102                     2060.3        2235           341           46
# 69347                     2064.5        2261           460           47
# 65472                     2070.7        2235           384           48
#
#          initial_time_seconds  game_duration_seconds  Player_rack_used_rate  \
# game_id
# 51857                    1200             632.083319               0.397959
# 31730                    1200             256.453327               0.236395
# 50150                    1200             245.164982               0.253501
# 18710                     780             798.728617               0.428571
# 46342                     780             841.983634               0.590110
# ...                       ...                    ...                    ...
# 5506                      900             471.077622               0.523810
# 26454                     900             421.667981               0.559524
# 14102                     900             295.437074               0.516484
# 69347                     900             248.825438               0.571429
# 65472                     900             582.157926               0.565476
#
#          rating_mode_CASUAL  rating_mode_RATED  Player_word_len  \
# game_id
# 51857                     0                  1         2.785714
# 31730                     0                  1         1.642857
# 50150                     0                  1         1.764706
# 18710                     1                  0         2.785714
# 46342                     1                  0         3.333333
# ...                     ...                ...              ...
# 5506                      0                  1         3.666667
# 26454                     0                  1         3.916667
# 14102                     0                  1         3.071429
# 69347                     0                  1         3.666667
# 65472                     0                  1         3.833333
#
#          Bot_nickname_HastyBot  lexicon_CSW21  max_overtime_minutes  \
# game_id
# 51857                        0              1                     1
# 31730                        1              1                     1
# 50150                        1              1                     1
# 18710                        0              1                     1
# 46342                        0              1                     1
# ...                        ...            ...                   ...
# 5506                         1              1                     1
# 26454                        1              1                     1
# 14102                        1              1                     1
# 69347                        1              1                     1
# 65472                        1              1                     1
#
#          Bot_score  Player_max_point  Player_min_point  lexicon_ECWL  \
# game_id
# 51857          416                93                 6             0
# 31730          646                12                 2             0
# 50150          592                24                 2             0
# 18710          548                31               -10             0
# 46342          467                72               -29             0
# ...            ...               ...               ...           ...
# 5506           494                77                 4             0
# 26454          500                71                 4             0
# 14102          587                72                 4             0
# 69347          496                87                 0             0
# 65472          397                66                 9             0
#
#          Bot_rack_used_rate  Predictions
# game_id
# 51857              0.561905  1701.048947
# 31730              0.723810  1290.474060
# 50150              0.615546  1313.474732
# 18710              0.670330  1667.187115
# 46342              0.629252  1714.523169
# ...                     ...          ...
# 5506               0.648352  2076.568232
# 26454              0.607143  2032.732449
# 14102              0.617582  2018.527940
# 69347              0.607143  2036.537249
# 65472              0.624176  2039.764209
#
# [22363 rows x 19 columns]

# %%
test_X.columns
# Out:
# Index(['hist_player_performance', 'Bot_rating', 'Player_score', 'Player_game',
#        'initial_time_seconds', 'game_duration_seconds',
#        'Player_rack_used_rate', 'rating_mode_CASUAL', 'rating_mode_RATED',
#        'Player_word_len', 'Bot_nickname_HastyBot', 'lexicon_CSW21',
#        'max_overtime_minutes', 'Bot_score', 'Player_max_point',
#        'Player_min_point', 'lexicon_ECWL', 'Bot_rack_used_rate',
#        'Predictions'],
#       dtype='object')

# %%
test_X["game_id"] = test_X.index
test_X
# Out:
#          hist_player_performance  Bot_rating  Player_score  Player_game  \
# game_id
# 51857                     1700.0        1990           331            1
# 31730                     1700.0        2269           118            1
# 50150                     1716.9        2220           135            2
# 18710                     1700.0        2065           274            1
# 46342                     1696.5        2065           332            2
# ...                          ...         ...           ...          ...
# 5506                      2133.3        2218           366           44
# 26454                     2056.9        2222           348           45
# 14102                     2060.3        2235           341           46
# 69347                     2064.5        2261           460           47
# 65472                     2070.7        2235           384           48
#
#          initial_time_seconds  game_duration_seconds  Player_rack_used_rate  \
# game_id
# 51857                    1200             632.083319               0.397959
# 31730                    1200             256.453327               0.236395
# 50150                    1200             245.164982               0.253501
# 18710                     780             798.728617               0.428571
# 46342                     780             841.983634               0.590110
# ...                       ...                    ...                    ...
# 5506                      900             471.077622               0.523810
# 26454                     900             421.667981               0.559524
# 14102                     900             295.437074               0.516484
# 69347                     900             248.825438               0.571429
# 65472                     900             582.157926               0.565476
#
#          rating_mode_CASUAL  rating_mode_RATED  Player_word_len  \
# game_id
# 51857                     0                  1         2.785714
# 31730                     0                  1         1.642857
# 50150                     0                  1         1.764706
# 18710                     1                  0         2.785714
# 46342                     1                  0         3.333333
# ...                     ...                ...              ...
# 5506                      0                  1         3.666667
# 26454                     0                  1         3.916667
# 14102                     0                  1         3.071429
# 69347                     0                  1         3.666667
# 65472                     0                  1         3.833333
#
#          Bot_nickname_HastyBot  lexicon_CSW21  max_overtime_minutes  \
# game_id
# 51857                        0              1                     1
# 31730                        1              1                     1
# 50150                        1              1                     1
# 18710                        0              1                     1
# 46342                        0              1                     1
# ...                        ...            ...                   ...
# 5506                         1              1                     1
# 26454                        1              1                     1
# 14102                        1              1                     1
# 69347                        1              1                     1
# 65472                        1              1                     1
#
#          Bot_score  Player_max_point  Player_min_point  lexicon_ECWL  \
# game_id
# 51857          416                93                 6             0
# 31730          646                12                 2             0
# 50150          592                24                 2             0
# 18710          548                31               -10             0
# 46342          467                72               -29             0
# ...            ...               ...               ...           ...
# 5506           494                77                 4             0
# 26454          500                71                 4             0
# 14102          587                72                 4             0
# 69347          496                87                 0             0
# 65472          397                66                 9             0
#
#          Bot_rack_used_rate  Predictions  game_id
# game_id
# 51857              0.561905  1701.048947    51857
# 31730              0.723810  1290.474060    31730
# 50150              0.615546  1313.474732    50150
# 18710              0.670330  1667.187115    18710
# 46342              0.629252  1714.523169    46342
# ...                     ...          ...      ...
# 5506               0.648352  2076.568232     5506
# 26454              0.607143  2032.732449    26454
# 14102              0.617582  2018.527940    14102
# 69347              0.607143  2036.537249    69347
# 65472              0.624176  2039.764209    65472
#
# [22363 rows x 20 columns]

# %%
from datetime import datetime

timestamp = datetime.now().strftime("%Y%m%d%H%M%S")
file_name = f"final_test_results_{timestamp}.csv"



final_test_results = test_X[["game_id", "Predictions"]]
final_test_results.rename(columns={"Predictions": "rating"}, inplace=True)
final_test_results_reset = final_test_results.reset_index(drop=True)
final_test_results_sorted = final_test_results_reset.sort_values(by='game_id', ascending=True)
final_test_results_sorted.to_csv(file_name, index=False)
# Out:
# C:\Users\inbox\AppData\Local\Temp\ipykernel_3992\1987286698.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_test_results.rename(columns={"Predictions": "rating"}, inplace=True)
